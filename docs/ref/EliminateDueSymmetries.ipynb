// %% [markdown]
// # EliminateDueSymmetries
//
// - Original source: [documentation:ref:eliminateduesymmetries](http://redberry.cc/documentation:ref:eliminateduesymmetries)
// - Back to local index: [Redberry Documentation](../Redberry.Documentation.ipynb)

// %%
#r "../../NRedberry.Core/bin/Debug/net10.0/NRedberry.Core.dll"
#r "../../NRedberry.Physics/bin/Debug/net10.0/NRedberry.Physics.dll"

using NRedberry;
using NRedberry.Groovy;
using NRedberry.Tensors;
using TensorFactory = NRedberry.Tensors.Tensors;

// %% [markdown]
// ---
//
//
// ### Description
//
// - `EliminateDueSymmetries` removes parts of expression, which are zero because of the symmetries.
//
// - `EliminateDueSymmetries` does not perform any structural simplifications (expand, eliminate metrics etc.), it is just using symmetries of expression.
//
// ### Examples
//
//
// Simplify expression where symmetric tensor is contracted with antisymmetric:
// ```groovy
// setAntiSymmetric 'f_mn'
// //g_mn is symmetric metric tensor
// println EliminateDueSymmetries >> 'f_mn * g^mn'.t
// ```
//
// ```text
//    > 0
// ```
//
// ---
//
// `EliminateDueSymmetries` also checks symmetries that follows from the structure of expressions:
// ```groovy
// println EliminateDueSymmetries >> '(t_amn - t_anm) * g^mn'.t
// ```
//
// ```text
//    > 0
// ```
//
// ---
//
// `EliminateDueSymmetries` works with expressions with arbitrary complexity:
// ```csharp
// var r = TensorFactory.ParseSimple("R_abc");
// int[] rSymmetry = [-1, 0, 2];
// r.SimpleIndices.Symmetries.AddSymmetry(rSymmetry.p);
//
// var a = TensorFactory.ParseSimple("A_ab");
// int[] aSymmetry = [1, 0];
// a.SimpleIndices.Symmetries.AddSymmetry(aSymmetry.p);
//
// var tensor = "((R_abc*A_de + R_bde*A_ac)*A^ce + R_adb)*(A_mf*R^mad - A_fm*R^dma)".t;
// var result = EliminateDueSymmetriesTransformation.Instance.Transform(tensor);
// ```
//
// ```text
//    > 0
// ```
//
// ---
//
// `EliminateDueSymmetries` applies to each part of expression:
// ```groovy
// def t = 'F_mn + g_mn*(A^mn - A^nm)'.t
// println EliminateDueSymmetries >> t
// ```
//
// ```text
//    > F_mn
// ```
//
// ---
//
// ### See also
//
// - Related guides: [applying and manipulating transformations](../guide/ApplyingAndManipulatingTransformations.ipynb), symmetries of tensors, [list of transformations](../guide/ListOfTransformations.ipynb)
// - JavaDocs: [EliminateDueSymmetriesTransformation](http://api.redberry.cc/redberry/1.1.9/java-api//cc/redberry/core/transformations/EliminateDueSymmetriesTransformation.html)
// - Source code: [EliminateDueSymmetriesTransformation.java](https://bitbucket.org/redberry/redberry/src/tip/core/src/main/java/cc/redberry/core/transformations/EliminateDueSymmetriesTransformation.java)
