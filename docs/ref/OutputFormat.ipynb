// %% [markdown]
// # OutputFormat
//
// - Original source: [documentation:ref:outputformat](http://redberry.cc/documentation:ref:outputformat)
// - Back to local index: [Redberry Documentation](../Redberry.Documentation.ipynb)

// %%
#r "../../NRedberry.Core/bin/Debug/net10.0/NRedberry.Core.dll"
#r "../../NRedberry.Physics/bin/Debug/net10.0/NRedberry.Physics.dll"

using NRedberry;
using NRedberry.Groovy;
using NRedberry.Tensors;
using TensorFactory = NRedberry.Tensors.Tensors;

// %% [markdown]
// ---
//
//
// ### Description
//
// `OutputFormat` is a enum that defines different formats of string representation of expressions in Redberry.
//
// There are several available output formats. In order to specify a particular one one can do:
// ```groovy
// import cc.redberry.groovy.Redberry
// import cc.redberry.core.context.OutputFormat
//
// use(Redberry){
//     def expr = 'a * F^{A}_{A m n} + g_mn'.t
//     println expr.toString(OutputFormat.Maple)
// }
// ```
//
// ```text
//   > a * F[m, n, ~A, A] + g_[m, n]
// ```
//
// The above result can be directly pasted to Maple system.
//
// The available output formats are:
// `Redberry`,
// `Cadabra`,
// `LaTeX`,
// `WolframMathematica`,
// `Maple`,
// `UTF8`,
// `SimpleRedberry`.  The last one can be used to print matrix objects in a convenient and human-readable format.
//
//
// One can set the default output format in the following way:
// ```groovy
// //set Cadabra output by default
// CC.defaultOutputFormat = OutputFormat.Cadabra
// ```
//
//
// ### See also
//
// - Related guides: [inputting and printing mathematical expressions](../guide/InputtingAndPrintingMathematicalExpressions.ipynb), [setting up matrix objects](../guide/SettingUpMatrixObjects.ipynb)
// - JavaDocs: [OutputFormat](http://api.redberry.cc/redberry/1.1.9/java-api//cc/redberry/core/context/OutputFormat.html)
// - Source code: [OutputFormat.java](https://bitbucket.org/redberry/redberry/src/tip/core/src/main/java/cc/redberry/core/context/OutputFormat.java)
