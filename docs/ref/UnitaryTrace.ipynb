// %% [markdown]
// # UnitaryTrace
//
// - Original source: [documentation:ref:unitarytrace](http://redberry.cc/documentation:ref:unitarytrace)
// - Back to local index: [Redberry Documentation](../Redberry.Documentation.ipynb)

// %%
#r "../../NRedberry.Core/bin/Debug/net10.0/NRedberry.Core.dll"
#r "../../NRedberry.Physics/bin/Debug/net10.0/NRedberry.Physics.dll"

using NRedberry;
using NRedberry.Groovy;
using NRedberry.Tensors;
using TensorFactory = NRedberry.Tensors.Tensors;

// %% [markdown]
// ---
//
//
// ### Description
//
// - `%% UnitaryTrace%%` calculates the  trace of SU(N) matrices in expressions.
//
//
// - By default `UnitaryTrace` uses notation `T_A` for SU(N) matrices, `f_ABC` for SU(N) structural constants, `d_ABC` for $d$-constatnts and `N` for dimension.
//
//
//
// - `%%UnitaryTrace`n`%%` specifies the notation for SU(N) matrices, structural constants, $d$-constants and dimension .
// ### Examples
//
// ---
//
// Calculate different traces:
// ```groovy
// //set up matrices
// defineMatrices 'T_A', Matrix2.matrix
// //structure constants are antisymmetric
// setAntiSymmetric 'f_ABC'
// //d-constants are symmetric
// setSymmetric 'd_ABC'
// println UnitaryTrace >> 'Tr[T_A*T_B]'.t
// ```
//
// ```text
//    > (1/2)*g_AB
// ```
//
// ```groovy
// UnitaryTrace >> 'Tr[T_A*T_B*T_C]'.t
// ```
//
// ```text
//    > (1/4*I)*f_{CAB}+(1/4)*d_{CAB}'
// ```
//
// ```groovy
// UnitaryTrace >> 'Tr[T_A*T^A + 1]'.t
// ```
//
// ```text
//    > N-1/2+(1/2)*N**2
// ```
//
// ```groovy
// UnitaryTrace >> 'Tr[T_A*T_B*T_C*T^A]'.t
// ```
//
// ```text
//    > (-(1/4)*N**(-1)+(1/4)*N)*g_{BC}
// ```
//
// ---
//
// Use  another notation for SU(N) objects:
// ```groovy
// //set up matrices
// defineMatrices 'm_a', Matrix4.matrix
// //structure constants are antisymmetric
// setAntiSymmetric 'a_abc'
// //d-constants are symmetric
// setSymmetric 's_abc'
// def uTrace = UnitaryTrace[[Matrix: 'm_a', f: 'a_abc', d: 's_abc', N: 'n']]
// println uTrace >> 'Tr[m^a*m_b*m^c*(p^b*m_a + p_a*m^b)*m_n]'.t
// ```
//
// ```text
//    > (-1/4*I)*n**(-1)*a_{n}^{ac}*p_{a}-(1/4)*n**(-1)*p_{a}*s_{n}^{ac}
// ```
//
// ### See also
//
// - Related guides: [applying and manipulating transformations](../guide/ApplyingAndManipulatingTransformations.ipynb), [Setting up matrix objects](../guide/SettingUpMatrixObjects.ipynb), [list of transformations](../guide/ListOfTransformations.ipynb)
// - Related tutorials: Compton scattering in QCD
// - Related transformations: UnitarySimplify, [DiracTrace](./DiracTrace.ipynb)
// - JavaDocs: [UnitaryTraceTransformation](http://api.redberry.cc/redberry/1.1.9/java-api//cc/redberry/physics/feyncalc/UnitaryTraceTransformation.html)
// - Source code: [UnitaryTraceTransformation.java](https://bitbucket.org/redberry/redberry/src/tip/physics/src/main/java/cc/redberry/physics/feyncalc/UnitaryTraceTransformation.java)
